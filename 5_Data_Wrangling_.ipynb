# %% [markdown]
# <a href="https://colab.research.google.com/github/AllamElsheikh/Projects/blob/main/Copy_of_04_Data_Wrangling_(AI_14).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Data wrangling**
# is a broad term used, often informally, to describe the process of
# transforming raw data to a clean and organized format ready for use.

# %%
import pandas as pd
import numpy as np

# %%
# Create URL
url = 'https://raw.githubusercontent.com/mhd911/Machine-Learning-A-to-Z/main/Titanic.csv'

url2="https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"
# Load data as a dataframe
dataframe = pd.read_csv(url2)
# Show first 5 rows
dataframe.head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
dataframe.tail()
# Out:
#                         Name PClass   Age   Sex  Survived  SexCode
# 1308      Zakarian, Mr Artun    3rd  27.0  male         0        0
# 1309  Zakarian, Mr Maprieder    3rd  26.0  male         0        0
# 1310        Zenni, Mr Philip    3rd  22.0  male         0        0
# 1311        Lievens, Mr Rene    3rd  24.0  male         0        0
# 1312          Zimmerman, Leo    3rd  29.0  male         0        0

# %%
dataframe.shape
# Out:
# (1313, 6)

# %%
# Show statistics
dataframe.describe()
# Out:
#               Age     Survived      SexCode
# count  756.000000  1313.000000  1313.000000
# mean    30.397989     0.342727     0.351866
# std     14.259049     0.474802     0.477734
# min      0.170000     0.000000     0.000000
# 25%     21.000000     0.000000     0.000000
# 50%     28.000000     0.000000     0.000000
# 75%     39.000000     1.000000     1.000000
# max     71.000000     1.000000     1.000000

# %%
dataframe.describe().T
# Out:
#            count       mean        std   min   25%   50%   75%   max
# Age        756.0  30.397989  14.259049  0.17  21.0  28.0  39.0  71.0
# Survived  1313.0   0.342727   0.474802  0.00   0.0   0.0   1.0   1.0
# SexCode   1313.0   0.351866   0.477734  0.00   0.0   0.0   1.0   1.0

# %%
dataframe.head(2)
# Out:
#                            Name PClass   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 1   Allison, Miss Helen Loraine    1st   2.0  female         0        1

# %%
dataframe.iloc[0]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: 0, dtype: object

# %%
# Select three rows from the second
dataframe.iloc[1:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 1         0        1
# 2         0        0
# 3         0        1

# %%
# Select first four rows
dataframe.iloc[:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1

# %%
# Select first four rows
dataframe.head(4)
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1

# %%
# Select  four rows  begin at the tenth row
dataframe.iloc[9:13]
# Out:
#                                                 Name PClass   Age     Sex  \
# 9                             Artagaveytia, Mr Ramon    1st  71.0    male
# 10                         Astor, Colonel John Jacob    1st  47.0    male
# 11  Astor, Mrs John Jacob (Madeleine Talmadge Force)    1st  19.0  female
# 12                      Aubert, Mrs Leontine Pauline    1st   NaN  female
#
#     Survived  SexCode
# 9          0        0
# 10         0        0
# 11         1        1
# 12         1        1

# %%
# Set index
dataframe = dataframe.set_index(dataframe['Name'])
dataframe.head()
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
#
#                                               PClass    Age     Sex  Survived  \
# Name
# Allen, Miss Elisabeth Walton                     1st  29.00  female         1
# Allison, Miss Helen Loraine                      1st   2.00  female         0
# Allison, Mr Hudson Joshua Creighton              1st  30.00    male         0
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female         0
# ...

# %% [markdown]
# **• loc is useful when the index of the DataFrame is a label (e.g., a string).**
#
# **• iloc works by looking for the position in the DataFrame.**

# %%
dataframe.loc['Allen, Miss Elisabeth Walton']
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: Allen, Miss Elisabeth Walton, dtype: object

# %% [markdown]
# ##**Selecting Rows Based on Conditionals**

# %%
# condition
dataframe['Sex'] == 'female'
# Out:
# Name
# Allen, Miss Elisabeth Walton                      True
# Allison, Miss Helen Loraine                       True
# Allison, Mr Hudson Joshua Creighton              False
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)     True
# Allison, Master Hudson Trevor                    False
#                                                  ...
# Zakarian, Mr Artun                               False
# Zakarian, Mr Maprieder                           False
# Zenni, Mr Philip                                 False
# Lievens, Mr Rene                                 False
# Zimmerman, Leo                                   False
# Name: Sex, Length: 1313, dtype: bool

# %%
dataframe[dataframe['Sex'] == 'female']
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Andrews, Miss Kornelia Theodosia                            Andrews, Miss Kornelia Theodosia
# Appleton, Mrs Edward Dale (Charlotte Lamson)    Appleton, Mrs Edward Dale (Charlotte Lamson)
# ...                                                                                      ...
# Vestrom, Miss Hulda Amanda Adolfina                      Vestrom, Miss Hulda Amanda Adolfina
# Wilkes, Mrs Ellen                                                          Wilkes, Mrs Ellen
# Yasbeck, Mrs Antoni                                                      Yasbeck, Mrs Antoni
# ...

# %%
dataframe[dataframe['Sex'] == 'female'].head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2.0
#
#                                  Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  female         1        1
# Allison, Miss Helen Loraine   female         0        1

# %%
male_df = dataframe[dataframe['Sex'] == 'male']
male_df
# Out:
#                                                                     Name  \
# Name
# Allison, Mr Hudson Joshua Creighton  Allison, Mr Hudson Joshua Creighton
# Allison, Master Hudson Trevor              Allison, Master Hudson Trevor
# Anderson, Mr Harry                                    Anderson, Mr Harry
# Andrews, Mr Thomas, jr                            Andrews, Mr Thomas, jr
# Artagaveytia, Mr Ramon                            Artagaveytia, Mr Ramon
# ...                                                                  ...
# Zakarian, Mr Artun                                    Zakarian, Mr Artun
# Zakarian, Mr Maprieder                            Zakarian, Mr Maprieder
# Zenni, Mr Philip                                        Zenni, Mr Philip
# Lievens, Mr Rene                                        Lievens, Mr Rene
# Zimmerman, Leo                                            Zimmerman, Leo
#
#                                     PClass    Age   Sex  Survived  SexCode
# Name
# ...

# %%
# Filter rows
retired_males =dataframe[(dataframe['Sex'] == 'male') & (dataframe['Age'] >= 60)]
retired_males.shape
# Out:
# (18, 6)

# %%
retired_males.head()
# Out:
#                                                             Name PClass   Age  \
# Name
# Artagaveytia, Mr Ramon                    Artagaveytia, Mr Ramon    1st  71.0
# Crosby, Captain Edward Gifford    Crosby, Captain Edward Gifford    1st  70.0
# Fortune, Mr Mark                                Fortune, Mr Mark    1st  64.0
# Frolicher-Stehli, Mr Maxmillian  Frolicher-Stehli, Mr Maxmillian    1st  60.0
# Goldschmidt, Mr George B                Goldschmidt, Mr George B    1st  71.0
#
#                                   Sex  Survived  SexCode
# Name
# Artagaveytia, Mr Ramon           male         0        0
# Crosby, Captain Edward Gifford   male         0        0
# Fortune, Mr Mark                 male         0        0
# Frolicher-Stehli, Mr Maxmillian  male         1        0
# Goldschmidt, Mr George B         male         0        0

# %%
children_df = dataframe [dataframe.Age <=15]
children_df.shape
# Out:
# (73, 6)

# %%
children_df
# Out:
#                                                                     Name  \
# Name
# Allison, Miss Helen Loraine                  Allison, Miss Helen Loraine
# Allison, Master Hudson Trevor              Allison, Master Hudson Trevor
# Carter, Miss Lucile Polk                        Carter, Miss Lucile Polk
# Carter, Master William T II                  Carter, Master William T II
# Dodge, Master Washington                        Dodge, Master Washington
# ...                                                                  ...
# Sandstrom, Miss Beatrice Irene            Sandstrom, Miss Beatrice Irene
# Van der Planke, Mr Leon                          Van der Planke, Mr Leon
# Van Impe, Miss Catharine                        Van Impe, Miss Catharine
# Vestrom, Miss Hulda Amanda Adolfina  Vestrom, Miss Hulda Amanda Adolfina
# Yasbeck, Mrs Antoni                                  Yasbeck, Mrs Antoni
#
#                                     PClass    Age     Sex  Survived  SexCode
# Name
# ...

# %%
# Replace values, show two rows
dataframe['Sex'].replace("female", "Woman").head(4)
# Out:
# Name
# Allen, Miss Elisabeth Walton                     Woman
# Allison, Miss Helen Loraine                      Woman
# Allison, Mr Hudson Joshua Creighton               male
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    Woman
# Name: Sex, dtype: object

# %%
# Replace "female" and "male with "Woman" and "Man"
dataframe['Sex'].replace(["female", "male"], ["Woman", "Man"]).head(5)
# Out:
# Name
# Allen, Miss Elisabeth Walton                     Woman
# Allison, Miss Helen Loraine                      Woman
# Allison, Mr Hudson Joshua Creighton                Man
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    Woman
# Allison, Master Hudson Trevor                      Man
# Name: Sex, dtype: object

# %%
dataframe.head()
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
#
#                                               PClass    Age     Sex  Survived  \
# Name
# Allen, Miss Elisabeth Walton                     1st  29.00  female         1
# Allison, Miss Helen Loraine                      1st   2.00  female         0
# Allison, Mr Hudson Joshua Creighton              1st  30.00    male         0
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female         0
# ...

# %%
# Replace "female" and "male with "2" and "1"
new_df=dataframe['Sex'].replace(["female", "male"], [2, 1])
new_df.head()
# Out:
# Name
# Allen, Miss Elisabeth Walton                     2
# Allison, Miss Helen Loraine                      2
# Allison, Mr Hudson Joshua Creighton              1
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    2
# Allison, Master Hudson Trevor                    1
# Name: Sex, dtype: int64

# %%
# Rename column, show two rows
dataframe = dataframe.rename(columns={'PClass': 'Passenger Class'})
dataframe.head()
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
#
#                                               Passenger Class    Age     Sex  \
# Name
# Allen, Miss Elisabeth Walton                              1st  29.00  female
# Allison, Miss Helen Loraine                               1st   2.00  female
# Allison, Mr Hudson Joshua Creighton                       1st  30.00    male
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00  female
# ...

# %%
# Rename columns, show two rows
dataframe = dataframe.rename(columns={'PClass': 'Passenger Class', 'Sex': 'Gender'})
dataframe.head(1)
# Out:
#                                                       Name Passenger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton             1st
#
#                                Age  Gender  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  29.0  female         1        1

# %%
dataframe.columns
# Out:
# Index(['Name', 'Passenger Class', 'Age', 'Gender', 'Survived', 'SexCode'], dtype='object')

# %%
# Calculate statistics
print('Maximum:', dataframe['Age'].max())
print('Minimum:', dataframe['Age'].min())
print('Mean:', dataframe['Age'].mean())
print('Median:', dataframe['Age'].median())
print('Mode:', dataframe['Age'].mode())
print('Sum:', dataframe['Age'].sum())
print('Count:', dataframe['Age'].count())
# Out:
# Maximum: 71.0
# Minimum: 0.17
# Mean: 30.397989417989418
# Median: 28.0
# Mode: 0    22.0
# dtype: float64
# Sum: 22980.88
# Count: 756

# %%
# Show counts
dataframe.count()
# Out:
# Name               1313
# Passenger Class    1313
# Age                 756
# Gender             1313
# Survived           1313
# SexCode            1313
# dtype: int64

# %%
dataframe['Gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dataframe['Passenger Class'].unique()
# Out:
# array(['1st', '2nd', '*', '3rd'], dtype=object)

# %%
print('Mode:', dataframe['Passenger Class'].mode())
# Out:
# Mode: 0    3rd
# dtype: object

# %%
dataframe [dataframe['Passenger Class']=='*']
# Out:
#                                     Name Passenger Class  Age Gender  \
# Name
# Jacobsohn Mr Samuel  Jacobsohn Mr Samuel               *  NaN   male
#
#                      Survived  SexCode
# Name
# Jacobsohn Mr Samuel         0        0

# %%
## Select missing values, show two rows
dataframe[dataframe['Age'].isnull()]
# Out:
#                                                       Name Passenger Class  \
# Name
# Aubert, Mrs Leontine Pauline  Aubert, Mrs Leontine Pauline             1st
# Barkworth, Mr Algernon H          Barkworth, Mr Algernon H             1st
# Baumann, Mr John D                      Baumann, Mr John D             1st
# Borebank, Mr John James            Borebank, Mr John James             1st
# Bradley, Mr George                      Bradley, Mr George             1st
# ...                                                    ...             ...
# Wiseman, Mr Phillippe                Wiseman, Mr Phillippe             3rd
# Yalsevac, Mr Ivan                        Yalsevac, Mr Ivan             3rd
# Youssef, Mr Gerios                      Youssef, Mr Gerios             3rd
# Zabour, Miss Hileni                    Zabour, Miss Hileni             3rd
# Zabour, Miss Tamini                    Zabour, Miss Tamini             3rd
#
#                               Age  Gender  Survived  SexCode
# ...

# %%
# Load data, set missing values
data_df = pd.read_csv(url, na_values=[np.nan, 'NONE', -999])
data_df.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
data_df.describe().T
# Out:
#            count       mean        std   min   25%   50%   75%   max
# Age        756.0  30.397989  14.259049  0.17  21.0  28.0  39.0  71.0
# Survived  1313.0   0.342727   0.474802  0.00   0.0   0.0   1.0   1.0

# %%
dataframe.drop('Gender', axis=1).head(2)
# Out:
#                                                       Name Passenger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton             1st
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine             1st
#
#                                Age  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  29.0         1        1
# Allison, Miss Helen Loraine    2.0         0        1

# %%
dataframe.head()
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
#
#                                               Passenger Class    Age  Gender  \
# Name
# Allen, Miss Elisabeth Walton                              1st  29.00  female
# Allison, Miss Helen Loraine                               1st   2.00  female
# Allison, Mr Hudson Joshua Creighton                       1st  30.00    male
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00  female
# ...

# %%
# Drop columns
dataframe.drop(['Age', 'Gender'], axis=1).head(2)
# Out:
#                                                       Name Passenger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton             1st
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine             1st
#
#                               Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton         1        1
# Allison, Miss Helen Loraine          0        1

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe.head()
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
#
#                                               Passenger Class    Age  Gender  \
# Name
# Allen, Miss Elisabeth Walton                              1st  29.00  female
# Allison, Miss Helen Loraine                               1st   2.00  female
# Allison, Mr Hudson Joshua Creighton                       1st  30.00    male
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00  female
# ...

# %%
df= dataframe.copy()
df.head(2)
# Out:
#                                                       Name Passenger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton             1st
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine             1st
#
#                                Age  Gender  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  29.0  female         1        1
# Allison, Miss Helen Loraine    2.0  female         0        1

# %%
df.reset_index(drop=True, inplace=True)
df.head(2)
# Out:
#                            Name Passenger Class   Age  Gender  Survived  \
# 0  Allen, Miss Elisabeth Walton             1st  29.0  female         1
# 1   Allison, Miss Helen Loraine             1st   2.0  female         0
#
#    SexCode
# 0        1
# 1        1

# %% [markdown]
# ## **Dropping Duplicate Rows**

# %%
dataframe.drop_duplicates()
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
# ...                                                                                      ...
# Zakarian, Mr Artun                                                        Zakarian, Mr Artun
# Zakarian, Mr Maprieder                                                Zakarian, Mr Maprieder
# Zenni, Mr Philip                                                            Zenni, Mr Philip
# ...

# %%
# Show number of rows
print("Number Of Rows In The Original DataFrame:", len(dataframe))
print("Number Of Rows After Droping duplicates: ", len(dataframe.drop_duplicates()))
# Out:
# Number Of Rows In The Original DataFrame: 1313
# Number Of Rows After Droping duplicates:  1313

# %%
# Drop duplicates
df.drop_duplicates(subset=['Gender'])
# Out:
#                                   Name Passenger Class   Age  Gender  \
# 0         Allen, Miss Elisabeth Walton             1st  29.0  female
# 2  Allison, Mr Hudson Joshua Creighton             1st  30.0    male
#
#    Survived  SexCode
# 0         1        1
# 2         0        0

# %%
df.head()
# Out:
#                                             Name Passenger Class    Age  \
# 0                   Allen, Miss Elisabeth Walton             1st  29.00
# 1                    Allison, Miss Helen Loraine             1st   2.00
# 2            Allison, Mr Hudson Joshua Creighton             1st  30.00
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00
# 4                  Allison, Master Hudson Trevor             1st   0.92
#
#    Gender  Survived  SexCode
# 0  female         1        1
# 1  female         0        1
# 2    male         0        0
# 3  female         0        1
# 4    male         1        0

# %%
# Drop duplicates
df.drop_duplicates(subset=['Gender'], keep='last')
# Out:
#                      Name Passenger Class   Age  Gender  Survived  SexCode
# 1307  Zabour, Miss Tamini             3rd   NaN  female         0        1
# 1312       Zimmerman, Leo             3rd  29.0    male         0        0

# %% [markdown]
# ## **Grouping Rows by Values**

# %%
dataframe.groupby('Gender').mean()
# Out:
#               Age  Survived  SexCode
# Gender
# female  29.396424  0.666667      1.0
# male    31.014338  0.166863      0.0

# %% [markdown]
# # **Looping Over a Column**

# %%
#iterate over every element in a column and apply some action

# Print first two names uppercased
for name in dataframe['Name'][0:10]:
  print(name.upper())
# Out:
# ALLEN, MISS ELISABETH WALTON
# ALLISON, MISS HELEN LORAINE
# ALLISON, MR HUDSON JOSHUA CREIGHTON
# ALLISON, MRS HUDSON JC (BESSIE WALDO DANIELS)
# ALLISON, MASTER HUDSON TREVOR
# ANDERSON, MR HARRY
# ANDREWS, MISS KORNELIA THEODOSIA
# ANDREWS, MR THOMAS, JR
# APPLETON, MRS EDWARD DALE (CHARLOTTE LAMSON)
# ARTAGAVEYTIA, MR RAMON

# %%
# Show first two names uppercased
[name.upper() for name in dataframe['Name'][0:2]]
# Out:
# ['ALLEN, MISS ELISABETH WALTON', 'ALLISON, MISS HELEN LORAINE']

# %% [markdown]
# ###Applying a Function Over All Elements in a Column

# %%
# Create function
def my_uppercase_fn(x):
 return x.upper()

# %%
# Apply function, show two rows
dataframe['Name'].apply(my_uppercase_fn)[0:2]
# Out:
# Name
# Allen, Miss Elisabeth Walton    ALLEN, MISS ELISABETH WALTON
# Allison, Miss Helen Loraine      ALLISON, MISS HELEN LORAINE
# Name: Name, dtype: object

# %%
dataframe['Name']=dataframe['Name'].apply(my_uppercase_fn)

# %%
dataframe.head()
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    ALLEN, MISS ELISABETH WALTON
# Allison, Miss Helen Loraine                                      ALLISON, MISS HELEN LORAINE
# Allison, Mr Hudson Joshua Creighton                      ALLISON, MR HUDSON JOSHUA CREIGHTON
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  ALLISON, MRS HUDSON JC (BESSIE WALDO DANIELS)
# Allison, Master Hudson Trevor                                  ALLISON, MASTER HUDSON TREVOR
#
#                                               Passenger Class    Age  Gender  \
# Name
# Allen, Miss Elisabeth Walton                              1st  29.00  female
# Allison, Miss Helen Loraine                               1st   2.00  female
# Allison, Mr Hudson Joshua Creighton                       1st  30.00    male
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00  female
# ...

# %%
df2=dataframe['Name'].apply(my_uppercase_fn)[0:2]
df2
# Out:
# Name
# Allen, Miss Elisabeth Walton    ALLEN, MISS ELISABETH WALTON
# Allison, Miss Helen Loraine      ALLISON, MISS HELEN LORAINE
# Name: Name, dtype: object

# %%
type(df2)
# Out:
# pandas.core.series.Series

# %%
dataframe.groupby('Gender').count()
# Out:
#         Name  Passenger Class  Age  Survived  SexCode
# Gender
# female   462              462  288       462      462
# male     851              851  468       851      851

# %%
# Group rows, apply function to groups
dataframe.groupby('Gender').apply(lambda x: x.count())
# Out:
#         Name  Passenger Class  Age  Gender  Survived  SexCode
# Gender
# female   462              462  288     462       462      462
# male     851              851  468     851       851      851
